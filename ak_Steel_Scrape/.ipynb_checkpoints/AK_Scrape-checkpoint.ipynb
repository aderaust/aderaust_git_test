# %%
import requests
from bs4 import BeautifulSoup as soup
import numpy as np
import pandas as pd
import re
import string
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler  


from sklearn.neural_network import MLPRegressor


from sklearn.model_selection import train_test_split

# %%
# username: E76723
# password: target01
# login-form-type: pwd

# %%
def log_in():
    '''This function logs the scrapper into the main menu with the approiate cookies'''
    login_data = {'username': 'E76723',
                  'password': 'target01',
                 'login-form-type': 'pwd'}

    
    session = requests.Session()
    
    # initial login page 
    
    login_link = "https://www.aksteelonline.com/webapp/wcs/stores/servlet/StoreView?storeId=10001&langId=-1"
    
    login_screen = session.get(login_link)

#     login_soup = soup(login_screen.content)

    # this f value is dynamic

#     login_data['f'] = login_soup.find('input', {'name': 'f'})['value']

   
    
    # form request link
    form_url = 'https://www.aksteelonline.com/pkmslogin.form'

    # sending login data into form
    main_page = session.post(form_url, login_data)
    
    # retreiving catalog page
    catalog_page = session.get(
        'https://www.aksteelonline.com/webapp/wcs/stores/servlet/LogonForm?storeId=10001&catalogId=10001')
    
    return catalog_page, session

# %%
catalog_page, session_logged_in = log_in()

# %%
# returning and converting BUY_NOW auctions

buy_now_raw = session_logged_in.get('https://www.aksteelonline.com/webapp/wcs/stores/servlet/CatalogSearchResultView?storeId=10001&catalogId=10001&ButtonB=Search+Buy+Now&countPerPage=50&sortSelect=product&page=0').text

buy_now = soup(buy_now_raw, 'html.parser')

# %%
# converting the table

buy_now_table = buy_now.find('table', {'border': "0", 'cellpadding':'2'})

# %%
# creating list of prices

def price_getter():

    price = buy_now_table.find_all('td', {'headers': 'WC_CatalogSearchResultDisplay_PriceHeader'})

    price_list = []
    for i in range(len(price)):

        price_list.append(float(re.sub(r'[^\d.]+', '', price[i].text)))
        
    return price_list

# %%
# creating list of gauges


def gauge_getter():
    gauge = buy_now_table.find_all('td', {'headers': 'WC_CatalogSearchResultDisplay_GAHeader'})


    gauge_list = []
    for i in range(len(gauge)):

        gauge_list.append(float(re.sub(r'[^\d.]+', '', gauge[i].text)))
        
    return gauge_list

# %%
# creating list of widths

def width_getter():

    width = buy_now_table.find_all('td', {'headers': 'WC_CatalogSearchResultDisplay_WDHeader'})


    width_list = []
    for i in range(len(width)):

        width_list.append(float(re.sub(r'[^\d.]+', '', width[i].text)))
        
    return width_list

# %%
# creating list of weights

def weight_getter():

    weight = buy_now_table.find_all('td', {'headers': 'WC_CatalogSearchResultDisplay_WeightHeader'})


    weight_list = []
    for i in range(len(weight)):

        weight_list.append(float(re.sub(r'[^\d.]+', '', weight[i].text)))
        
    return weight_list

# %%
# creating list of locations


        
def location_getter():

    location = buy_now_table.find_all('td', {'headers': 'WC_CatalogSearchResultDisplay_LocationHeader'})


    location_list = []
    for i in range(len(location)):

        location_list.append(location[i].text.strip('\r\n\t\t\t\t\t'))
    return location_list

# %%
# scraping inner-table

inner_table = buy_now_table.find_all('table', {'cellpadding' : "0", 'cellspacing' : "0", 'border' : "3",
                                    'width' : "100%"})

# %%
# creating list of defects

def defect_getter():

    defect_list = []

    for i in range(len(inner_table)):

        if inner_table[i].find(text = re.compile(r"\bDefect\b")) is None:
            defect_list.append(None)
        else:
            defect_list.append(inner_table[i].find(text = re.compile(r"\bDefect\b")).findNext('td').text.rstrip().strip('\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'))
    return defect_list
#     print(i)

# all_defects = buy_now_table.find_all(text = re.compile(r"\bDefect\b"))    

# buy_now_table.find(text = re.compile(r"\bDefect\b")).findNext('td').text

# %%
# creating list of lin-feet

def linfeet_getter():
    
    lin_feet_list = []
    for i in range(len(inner_table)):

        if inner_table[i].find(text = re.compile("Lin. Ft.")) is None:
            lin_feet_list.append(None)
        else:
            lin_feet_list.append(float(inner_table[i].find(text = re.compile("Lin. Ft.")).findNext('td').text.rstrip().strip('\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t').replace(",","")))
            
    return lin_feet_list

# %%
# creating index list of unique codes

# table cellpadding="0" cellspacing="0" border="0" width="100%"

index_table = buy_now_table.find_all('td', {'align':'left'})

def index_getter():
    index_list = []

    for i in range(len(index_table)):
        index_list.append(index_table[i].text.rstrip().strip('\r\n\t\t\t\t\t\t\t\t\t\xa0\xa0\xa0\r\n\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t'))
    return index_list

# %%
# retreiving chemistry data

chem_table = buy_now_table.find_all(text = re.compile("C-"))

def chem_getter():

    chem_list = []
    for i in range(len(chem_table)):


        digit_string = re.sub('[^0-9\.]',' ', chem_table[i].rstrip())
        
#         if digit_string is None:
#             chem_list.append(None)
            
#             pass
        

        pretty_string= [float(x) for x in digit_string.split()]

        #logic if code does or does not contain heat number

        
        
        
        if pretty_string[0] > 100:
            pretty_string.pop(0)
        
        if len(pretty_string) != 8:
            chem_list.append(np.repeat(np.nan, 8))
        

        
        else: chem_list.append(pretty_string)
            
            

    return np.array(chem_list)


chem_getter_test = chem_getter()

# %%
# chem_list = []
# pretty_string_test = []
# for i in range(len(chem_table)):


#     digit_string = re.sub('[^0-9\.]',' ', chem_table[i].rstrip())

#     if digit_string is None:
#         chem_list.append(None)

#         pass


#     pretty_string= [float(x) for x in digit_string.split()]
#     pretty_string_test.append(pretty_string)

# #     #logic if code does or does not contain heat number

# #     if pretty_string[0] > 100:
# #         pretty_string.pop(0)

# #     if pretty_string =! 
    
    
#     chem_list.append(pretty_string)



# digit_string.split()

# %%
# logic for making a dynamic page count 


# >>> from bs4 import BeautifulSoup
# >>> data = """
# ... <h4>Testing</h4>
# ... <h3>Test</h3>
# ... <h3>Test2</h3>
# ... <h4>Testing2</h4>
# ... """
# >>> soup = BeautifulSoup(data)
# >>> element = soup.find('h3', text='Test')
# >>> element.find_previous_sibling('h4')
# <h4>Testing</h4>

url_count = int(buy_now.find('a', {'id' :"WC_PageURL_Link_Next"}).find_previous_sibling('a').text.rstrip().strip('\r\n\t\t\t\t\t'))

# %%
# creating list of urls

skeleton_url = "https://www.aksteelonline.com/webapp/wcs/stores/servlet/CatalogSearchResultView?storeId=10001&catalogId=10001&ButtonB=Search+Buy+Now&countPerPage=50&sortSelect=product&page="


page_urls = []
for i in range(url_count):
    page_urls.append(skeleton_url + str(i))

# %%
def data_getter():

    price_master_list = []
    gauge_master_list = []
    width_master_list = []
    weight_master_list = []
    location_master_list = []
    defect_master_list = []
    linfeet_master_list = []
    index_master_list = []
    # chem_master_list = []


    carbon_master = []
    manganese_master = []
    phosphorus_master = []
    sulfur_master = []
    silicon_master = []
    aluminium_master = []
    niobium_master = []
    vanadium_master = []










    for page in page_urls:
    #     print(page)

        # retreiving current page

        buy_now_raw = session_logged_in.get(page).text

        buy_now = soup(buy_now_raw, 'html.parser')


        buy_now_table = buy_now.find('table', {'border': "0", 'cellpadding':'2'})

        # pulling all prices

        current_price = price_getter()

        price_master_list.extend(current_price)


        # pulling all gauges

        current_gauge = gauge_getter()

        gauge_master_list.extend(current_gauge)

        # pulling all widths

        current_width = width_getter()

        width_master_list.extend(current_width)

        # pulling all weights

        current_weight = weight_getter()

        weight_master_list.extend(current_weight)

        # pulling all locations

        current_location = location_getter()

        location_master_list.extend(current_location)

        ####



        inner_table = buy_now_table.find_all('table', {'cellpadding' : "0", 'cellspacing' : "0", 'border' : "3",
                                        'width' : "100%"})



        # pulling all defects

        current_defect = defect_getter()

        defect_master_list.extend(current_defect)


        # pulling all linfeet

        current_linfeet = linfeet_getter()

        linfeet_master_list.extend(current_linfeet) 


        ######

        index_table = buy_now_table.find_all('td', {'align':'left'})


        # pulling all index

        current_index = index_getter()

        index_master_list.extend(current_index)


        #######
        chem_table = buy_now_table.find_all(text = re.compile("C-"))

        # pulling all chemicals

        current_chem = chem_getter()
    #     print(current_chem)

    #     chem_master_list.extend(current_chem)


        carbon_master.extend(current_chem[:,0].tolist())
        manganese_master.extend(current_chem[:,1].tolist())
        phosphorus_master.extend(current_chem[:,2].tolist())
        sulfur_master.extend(current_chem[:,3].tolist())
        silicon_master.extend(current_chem[:,4].tolist())
        aluminium_master.extend(current_chem[:,5].tolist())
        niobium_master.extend(current_chem[:,6].tolist())
        vanadium_master.extend(current_chem[:,7].tolist())


    comprehensive_dict = {"index" : index_master_list, 'price' : price_master_list ,'carbon' : carbon_master, 'manganese' : manganese_master,
    'phosphorus': phosphorus_master, 'sulfur' : sulfur_master, 'silicon' : silicon_master,
    'aluminium' : aluminium_master, 'niobium' : niobium_master, 'vanadium' : vanadium_master,
    'gauge' : gauge_master_list, 'width' : width_master_list, 'weight' : weight_master_list, 'location' : location_master_list,
    'defect': defect_master_list, "linear feat" : linfeet_master_list}


    ak_dict = pd.DataFrame(comprehensive_dict)

    return ak_dict
    
    
ak_dict = data_getter()

# %%
# cleaning df 

ak_dict['defect_code'] = ak_dict.defect.str.extract('(\d+)')

ak_dict = ak_dict.dropna()

# %%
# saving df
ak_dict.to_csv('final_ak_df',index = False)

# %%
# splitting data into test and train

train, test = train_test_split(ak_dict)

# %%
# creating train and test 

X_train = train.loc[:, ['carbon', 'manganese', 'phosphorus',
              'sulfur', 'silicon', 'aluminium', 'niobium',
              'vanadium', 'gauge', 'width',
              'weight', 'linear feat']].values

y_train = train.loc[:, "price"].values

X_test = test.loc[:, ['carbon', 'manganese', 'phosphorus',
              'sulfur', 'silicon', 'aluminium', 'niobium',
              'vanadium', 'gauge', 'width',
              'weight', 'linear feat']].values

# 'defect_code'

y_test = test.loc[:, "price"].values




# standardizing input data for mlp regression 

x_scaler = StandardScaler()  
x_scaler.fit(X_train)  

X_train = x_scaler.transform(X_train)  

# apply same transformation to test data
X_test = x_scaler.transform(X_test)  



# standardizing output data for mlp regression 

y_train = y_train.reshape(-1,1)

y_scaler = StandardScaler()  
y_scaler.fit(y_train)  

y_train = y_scaler.transform(y_train)  

# apply same transformation to test data

y_test = y_test.reshape(-1,1)


y_test = y_scaler.transform(y_test)

# %%
ak_regressor = MLPRegressor()

ak_regressor.fit(X_train, np.ravel(y_train))

ak_regressor.score(X_test, np.ravel(y_test))

# %%
y_scaler.inverse_transform(ak_regressor.predict(X_test[3].reshape(1,-1)))

# %%
test

# %%
test = ak_dict.dropna()

# %%
ak_dict.drop_duplicates()
# Out:
#           index  price  carbon  manganese  phosphorus  sulfur  silicon  \
# 0   676081-02AA   30.0  0.0095     0.2900      0.0240  0.0018   0.3500
# 1    668228-10B   30.0  0.0054     0.3330      0.0200  0.0012   0.2940
# 2     519624-05   30.0  0.0087     0.3200      0.0220  0.0010   0.3400
# 3   684778-06AA   30.0  0.0038     0.3320      0.0150  0.0006   0.3000
# 4    681110-02A   30.0  0.0038     0.3320      0.0150  0.0006   0.3000
# 5     686359-01   30.0  0.0052     0.4310      0.0160  0.0006   0.3170
# 6   684481-04BA   30.0  0.0096     0.3400      0.0230  0.0013   0.3900
# 7   684592-01AA   30.0  0.0100     0.3100      0.0230  0.0015   0.3700
# 8   664153-03AA   30.0  0.0060     0.4300      0.0180  0.0010   0.3240
# 9   664153-03AB   30.0  0.0060     0.4300      0.0180  0.0010   0.3240
# 10  684788-06BB   30.0  0.0039     0.3620      0.0160  0.0008   0.3150
# 11  684222-04BA   30.0  0.0070     0.3480      0.0170  0.0006   0.3190
# 12   684187-07A   30.0  0.0060     0.3350      0.0180  0.0011   0.3640
# 13   690705-06B   30.0  0.0046     0.3400      0.0190  0.0003   0.3660
# 14  692827-02AA   30.0  0.0106     0.3200      0.0230  0.0013   0.4100
# 15  692475-07BA   30.0  0.0047     0.2870      0.0170  0.0009   0.3010
# 16   700795-01A   30.0  0.0084     0.3200      0.0240  0.0025   0.3600
# 17  700734-03AA   30.0  0.0091     0.2400      0.0220  0.0032   0.3700
# 18  700734-03AB   30.0  0.0091     0.2400      0.0220  0.0032   0.3700
# 19  D-190611-39   26.0  0.1991     1.9528      0.0099  0.0033   1.5762
# 20  D-190611-40   26.0  0.1991     1.9528      0.0099  0.0033   1.5762
# 21  D-190611-44   26.0  0.0658     1.2478      0.0104  0.0029   0.0233
# 22  D-190611-17   26.0  0.0495     0.2041      0.0153  0.0075   0.0089
# 23  D-190611-45   26.0  0.0872     2.0842      0.0128  0.0013   0.3626
# 24  D-190611-14   33.0  0.0592     0.5603      0.0104  0.0074   0.0211
# 25  D-190611-18   33.0  0.0372     0.2442      0.0146  0.0073   0.0105
# 26  D-190611-15   33.0  0.0025     0.3527      0.0454  0.0063   0.0069
# 27  D-190611-16   33.0  0.0025     0.3401      0.0436  0.0056   0.0059
# 28   659172-03A   65.0  0.0128     0.3300      0.0240  0.0009   0.4200
# 29   659172-03G   65.0  0.0128     0.3300      0.0240  0.0009   0.4200
# 30   587815-04N   65.0  0.0104     0.3100      0.0250  0.0009   0.3900
# 31  682372-01AG   65.0  0.0109     0.3200      0.0250  0.0017   0.4200
# 32   613698-11B   65.0  0.0101     0.3300      0.0250  0.0014   0.3900
# 33   647145-01C   65.0  0.0099     0.2700      0.0230  0.0018   0.4300
# 34  677317-05AC   65.0  0.0093     0.2900      0.0290  0.0018   0.4200
# 35   678018-11D   65.0  0.0105     0.3400      0.0250  0.0012   0.4200
# 36   670491-02B   65.0  0.0131     0.3400      0.0260  0.0007   0.4300
# 36            AK STEEL CORPORATION    Rockport, IN
# 37    PRECISION STRIP, INC.(MINSTER)   Minster, OH
# 38    PRECISION STRIP, INC.(MINSTER)   Minster, OH
# 39    PRECISION STRIP, INC.(MINSTER)   Minster, OH
# 40  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 41  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 42  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 43  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 44  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 45  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 46  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 47  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 48  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
# 49  PRECISION STRIP (MIDDLETOWN)    Middletown, OH
#
#                                defect  linear feat
# 0             0615 CTG BLOWER STREAKS       1985.0
# 1              0933 LITE COIL-QUALITY        847.0
# 2           0618 CTG BUILD UP KNUCKLE      11546.0
# 3              0616 COATING SCRATCHES       3512.0
# 4                  0606 COATING DENTS       4232.0
# 5                  0636 COATING DROSS       5774.0
# 6              0933 LITE COIL-QUALITY       1213.0
# 7         2939 DISTRESSED INV PRV DIV       1426.0
# 8                   0675 CTG SLOW RUN       1418.0
# 9                   0675 CTG SLOW RUN       1418.0
# 10             0613 COATING UNIT STOP       2192.0
# 11             0933 LITE COIL-QUALITY        947.0
# 12  0677 AL STAINLESS INTERFACE UNCTD        754.0
# 13             0933 LITE COIL-QUALITY        490.0
# 14            0602 CTG BUILDUP FLANGE       1510.0
# 15  0677 AL STAINLESS INTERFACE UNCTD       2296.0
# 16             0665 CTG CL KNIFE MRKS       2683.0
# 17            0602 CTG BUILDUP FLANGE       2071.0
# 18            0602 CTG BUILDUP FLANGE       1241.0
# 19                               None          NaN
# 20                               None          NaN
# 21                               None          NaN
# 22                               None          NaN
# 23                               None          NaN
# 24                               None          NaN
# 25                               None          NaN
# 26                               None          NaN
# 27                               None          NaN
# 28                    0117 HSM GOUGES       2925.0
# 29                    0117 HSM GOUGES       2925.0
# 30                 0136 HSM DRAG LINE       2663.0
# 31            0826 APL UNDER ANNEALED       1180.0
# 32         0012 MELT LINE LAMINATIONS       2663.0
# 33              0023 MELT BLACK LINES       2796.0
# 34                   0132 HSM SCRATCH       4373.0
# 35             2913 OUTSIDE PROCESSOR        994.0
# 36             0933 LITE COIL-QUALITY       1634.0
# 37         2914 PRIME ORDER CANCELLED       2383.0
# 38             0841 APL BRITE SCRATCH       3396.0
# 39         2914 PRIME ORDER CANCELLED       2833.0
# 40             2913 OUTSIDE PROCESSOR       4585.0
# 41             2913 OUTSIDE PROCESSOR       4585.0
# 42           0929 UNIDENTFD ROLL MARK       1455.0
# 43           0929 UNIDENTFD ROLL MARK       1455.0
# 44           0929 UNIDENTFD ROLL MARK       1549.0
# 45           0929 UNIDENTFD ROLL MARK       1549.0
# 46           0929 UNIDENTFD ROLL MARK       1278.0
# 47           0929 UNIDENTFD ROLL MARK       1278.0
# 48           0929 UNIDENTFD ROLL MARK       1530.0
# 49           0929 UNIDENTFD ROLL MARK       1530.0
